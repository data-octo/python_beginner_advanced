# %% [markdown]
# # Preface
#
# ## Set expectation
#
# - Know how to set up python development environment
# - Know basic coding knowledge and coding with Python
# - Know how to draw graphics with Python
# - Know how to make simple games with Python
# - Know how to use Python for data analysis, machine learning and deep learning
#
# ## Why Coding
#
# - Future of AI
# - Competitive Advantage

# %% [markdown]
# ### How each chapter is organized
#
# - Examples of Code that can be run in the cell
#
# - Explaination about the code with study points
#
# - Pratice of the study points

# %% [markdown]
# ### Prerequisites
#
# You should have a basic understanding of Computer Programming terminologies. A basic understanding of any of the programming languages is a plus.

# %% [markdown]
# ## Video of Python Coding

# %% [markdown]
# ## Video of Python Graphics
#
# <video width="320" height="240" controls>
#   <source src="images/python-turtle-degrees.mov" type="video/mp4">
# </video>

# %% [markdown]
# ## Video of Python Gaming
#
# Flappy Bird, Super Mario, Gomoku
#
# ![flappy bird](images/python-flappy-bird.png "image")

# %% [markdown]
# ## Video of Python for Data Science
#
# Analysis, Visualization, Prediction

# %% [markdown]
# ## Video of Python for AI
#
# Gomoku with AlphaZero, Image Style Transfer, Face Swap
