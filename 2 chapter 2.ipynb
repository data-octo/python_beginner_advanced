# %% [markdown]
# # What's Python
#
# ## Introduction
#
# - Basics
# - Graphics
# - Gaming
# - Data Science
# - AI
#
# ## IDE
#
# ### Local Install
#
# - Anaconda
# - Visual Studio Code
# - Pycharm
#
# ### Online IDE
#
# - Google Colab
# - Kaggle Notebook
# - Trinket
#
# ## How to learn
#
# - Online Video
# - In class training
# - In house learning
# - Team learning
# - Practice
