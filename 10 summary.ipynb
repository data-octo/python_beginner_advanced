# %% [markdown]
# # Summary
#
# More to learn
# - Generators
# - List Comprehensions
# - Multiple Function Arguments
# - Regular Expressions
# - Exception Handling
# - Sets
# - Serialization
# - Partial functions
# - Code Introspection
# - Closures
# - Decorators
# - Map, Filter, Reduce
